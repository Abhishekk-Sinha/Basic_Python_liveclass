# %%
x = 5;
y = 10;
x = x + y;
x = x - y;
x = x - y;

# %%
x
# Out:
# -5

# %%
y
# Out:
# 10

# %%
1+2
# Out:
# 3

# %%
x = 10
x = x+5
print(x)
# Out:
# 15

# %%
v-ar = 10
print(v-ar)
# Out:
#   File "<ipython-input-3-0caa4ed901c5>", line 1
#     v-ar = 10
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
name = "johm"
age = 25
print("My name is", name, "and I am ", age, "years old")
# Out:
# My name is johm and I am  25 years old

# %%
a = 10
a
# Out:
# 10

# %%
sudh = 324335235
sudh
# Out:
# 324335235

# %%
type(sudh)
# Out:
# int

# %%
type(a)
# Out:
# int

# %%
s = "apple"

# %%
type(s)
# Out:
# str

# %%
s1 ='this is my first python lecture'

# %%
s1
# Out:
# 'this is my first python lecture'

# %%
type(s1)
# Out:
# str

# %%
f = 456.673
type(f)
# Out:
# float

# %%
c = 5 + 6j

# %%
type(c)
# Out:
# complex

# %%
c.real
# Out:
# 5.0

# %%
c.imag
# Out:
# 6.0

# %%
b = True

# %%
type(b)
# Out:
# bool

# %%
b1 = False

# %%
b1
# Out:
# False

# %%
type(b1)
# Out:
# bool

# %%
a1 = 45
a2 = 34

# %%
a1+a2
# Out:
# 79

# %%
a1*a2
# Out:
# 1530

# %%
a1/a2
# Out:
# 1.3235294117647058

# %%
a1-a2
# Out:
# 11

# %%
45/34
# Out:
# 1.3235294117647058

# %%
a1, a2 = 34,45

# %%
a1
# Out:
# 34

# %%
a2
# Out:
# 45

# %%
a,b,c,d = 354, "sudh", 34.34, True

# %%
a

# %%
b
# Out:
# 'sudh'

# %%
c
# Out:
# 34.34

# %%
d
# Out:
# True

# %%
# %a =234
# Out:
# UsageError: Line magic function `%a` not found.

# %%
b = 234

# %%
@h = 3543
# Out:
#   File "<ipython-input-41-21619ace1458>", line 1
#     @h = 3543
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
_a = 34

# %%
-b = 234
# Out:
#   File "<ipython-input-43-bee40060e6ca>", line 1
#     -b = 234
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
True = 45
# Out:
#   File "<ipython-input-44-8726ea56ada1>", line 1
#     True = 45
#     ^
# SyntaxError: cannot assign to True

# %%
int = 345

# %%
int
# Out:
# 345

# %%
b1 = True

# %%
b2 = False

# %%
b1-b2
# Out:
# 1

# %%
b2-b1
# Out:
# -1

# %%
b1*b2
# Out:
# 0

# %%
b1*b1
# Out:
# 1

# %%
b1/b2
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-54-834e810e37ec> in <cell line: 1>()
# ----> 1 b1/b2
#
# ZeroDivisionError: division by zero

# %%
s1 = "my name is Abhi"

# %%
s1
# Out:
# 'my name is Abhi'

# %%
type(s1)
# Out:
# str

# %%
s2 = "thus is my first python class for data science"

# %%
s2
# Out:
# 'thus is my first python class for data science'
